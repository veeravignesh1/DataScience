# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig,ax = plt.subplots()
x=np.linspace(0,20,200)
ax.plot(x,np.sin(x),'--')
plt.show()

# %% [markdown]
# - Marker
# - Linestyle
# - color
# - set_xlabel
# - set_ylabel
# - set_title
# - subplots
# - sharey
# - twinx
# - tick_params
# - annotate --> xy , xytext
# - arrowprops {} # Default property
# - set_xticklabels
# - set_yticklabels
# - bottom
# - rotation
# - legend
# - label
# - bar
#     - yerr
# - hist
#     - histtype = step
#     - bins
# - error plot
# - box plot
# - scatter plots
# - plt.style.use()
#     - bmh
#     - seaborn-colorblind
#     - ggplot
#     - seaborn
# - fig.savefig('filename.png')
#     - jpg or png or svg
#     - quality ( 0 to 100)
#     - dpi
# - fig.set_size_inches([3,5])
# -

# %%
plt.style.use("seaborn")
fig,ax = plt.subplots(2,1)
ax[0].plot(x,np.sin(x))
ax[1].plot(x,np.cos(x))
ax[1].set_xlabel("Sample")
plt.show()

# %%
fig.set_label?

# %%
fig,ax=plt.subplots()

# %%
type(fig),type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %%
ax[1].s
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001F7C8702848>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001F7C87ACF48>],
#       dtype=object)

# %%
fig.
