# %% [markdown]
# # My notebook title
#
# Date: 2018-09-15
# Author: Veera Vignesh
# Categories: Jupyter Notebook
# Tags: Python, Machine Learning
# <!--eofm-->

# %% [markdown]
# ## Round off Error

# %%
22/7
# Out:
# 3.142857142857143

# %%
len(str(22/7)) #15 decimal places and 1point.& 1 whole number char
# Out:
# 17

# %%
import math
print(math.ceil(10.01239873)) #Reurns the smallest possible integer >=x
print(math.floor(10.01239873)) #Returns the largest possible integer <=x
# Out:
# 11
# 10

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'pi',
#  'pow',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import random
list1 = [random.randint(3,6) for s in range(1,51)] #Using List Comprehension
# len(list1) --> Checking the size of the list
print(list1)
# Out:
# [5, 3, 4, 5, 3, 6, 3, 6, 6, 4, 5, 4, 6, 5, 5, 6, 6, 5, 5, 5, 3, 6, 3, 3, 4, 6, 6, 5, 3, 5, 4, 6, 3, 4, 6, 5, 4, 6, 4, 5, 6, 3, 6, 3, 3, 3, 4, 5, 6, 4]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Random already imported
x,y=random.randint(1,50),random.randint(1,50)
RandomNumber= x**y
print(f'The value of x is {x} and y is {y}, x^y is {RandomNumber}')
# Out:
# The value of x is 23 and y is 18, x^y is 3244150909895248285300369

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Random3=random.randint(1,10)
print(Random3) #Check random number
for i in range(0,Random3):
    print("your name",end=',')
# Out:
# 9
# your name,your name,your name,your name,your name,your name,your name,your name,your name,

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Random4=random.uniform(1,10)
round(Random4,2)
# Out:
# 4.91

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list5=[random.randint(1,i) for i in range(2,52)]
print(list5)
# Out:
# [1, 2, 3, 2, 2, 2, 7, 4, 3, 7, 6, 11, 8, 5, 5, 8, 4, 2, 2, 8, 18, 17, 1, 15, 26, 12, 19, 26, 2, 26, 16, 24, 22, 21, 33, 12, 35, 6, 20, 14, 34, 15, 36, 12, 36, 7, 30, 18, 33, 46]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x=eval(input("Enter a number for x: "))
y=eval(input("Enter a number for y: "))

print(round(abs(x-y)/(x+y),2))
# Out:
# Enter a number for x: 10
# Enter a number for y: 20
# 0.33

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
inputs = eval(input("Enter the time in seconds: "))
minutes = inputs//60
seconds = inputs-minutes*60
print(f'It has {minutes} minutes and {seconds} seconds ')
# Out:
# Enter the time in seconds: 10
# It has 0 minutes and 10 seconds

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
hour = eval(input("Enter hour: "))
forecast = eval(input("How many hours ahead? "))
new_hour = (hour+forecast)%12
print(f"New Hour:{new_hour} o'clock")
# Out:
# Enter hour: 20
# How many hours ahead? 2
# New Hour:10 o'clock

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
number = eval(input('Enter a power: '))
power= 2**number
print(f'The last digit of 2 Raised to {number} is {power%10}')
# Out:
# Enter a power: 2
# The last digit of 2 Raised to 2 is 4

# %%
number = eval(input('Enter a power: '))
power= 2**number
print(power)
print(f'The last two digits of 2 Raised to {number} is {power%100}')
# Out:
# Enter a power: 5
# 32
# The last two digits of 2 Raised to 5 is 32

# %%
power = eval(input('Enter a power: '))
number = eval(input('Enter the number of digits: '))
raised = str(2**power)
# print(raised)
print(f'The last {number} digits of 2 Raised to {power} is {raised[-number:]}')


#In this example raised is converted to str to handle 0 in the -3 position..
# If it is of type int python omits the 0 and displays only 2 digits. SO converted to (str)
# Out:
# Enter a power: 5
# Enter the number of digits: 6
# The last 6 digits of 2 Raised to 5 is 32

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
kilo = eval(input("Enter the weight in Kilograms: "))
pounds = round(kilo * 2.20462,1)
print(f'The weight in pounds is {pounds}')
# Out:
# Enter the weight in Kilograms: 13
# The weight in pounds is 28.7

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Using math function
import math
number= eval(input("Enter a number for which you need factorial: "))
print(f'Factorial of the number is {math.factorial(number)}')
# Out:
# Enter a number for which you need factorial: 15
# Factorial of the number is 1307674368000

# %%
#Using recursive function:
def factorial(number):
    if number==0:
        return 1
    else:
        return number*factorial(number-1)
number= eval(input("Enter a number for which you need factorial: "))
fact=factorial(number)
print(f'The factorial of {number} is {fact}')
# Out:
# Enter a number for which you need factorial: 45
# The factorial of 45 is 119622220865480194561963161495657715064383733760000000000

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from math import *
number= eval(input("Enter a number: "))
print(f'The sine of the number is :f.2{math.sin(number)}')
print(f'The sine of the number is {math.cos(number)}')
print(f'The sine of the number is {math.tan(number)}')
# Out:
# Enter a number: 15
# The sine of the number is :f.20.6502878401571168
# The sine of the number is -0.7596879128588213
# The sine of the number is -0.8559934009085188

# %%
print(f'The sine of the number is {math.sin(number)}')
# Out:
# The sine of the number is 0.6502878401571168

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import nb2hugo

# %%
nb2hugo
