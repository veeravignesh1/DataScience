# %% [markdown]
# ## 1.8 Exercises:

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("**********")
print("**********")
print("**********")
print("**********")
# Out:
# **********
# **********
# **********
# **********

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print("**********")
print("*        *")
print("*        *")
print("**********")
# Out:
# **********
# *        *
# *        *
# **********

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print('*')
print('**')
print('***')
print('****')
# Out:
# *
# **
# ***
# ****

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print((512-282)/(47*48+5))
# Out:
# 0.1017249004865104

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
number=eval(input("Enter a number: "))
square=number*number
print('The square of', 5,end=" ",sep=" ")
print('is',square,end=".")
# Out:
# Enter a number: 4
# The square of 5 is 16.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = eval(input("Enter a number: "))
print(num,2*num,3*num,4*num,5*num,sep="--")
# Out:
# Enter a number: 7
# 7--14--21--28--35

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
weight_in_pount=eval(input("Enter your weight in pounds: "))
weight_in_kg=2.2*weight_in_pount
print("Your weight in kgs is",weight_in_kg)
# Out:
# Enter your weight in pounds: 1
# Your weight in kgs is 2.2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num1=eval(input("Enter first number: "))
num2=eval(input("Enter second number: "))
num3=eval(input("Enter third number: "))
total=num1+num2+num3
average=total/3
print("The Total is",total)
print("The Average is",average)
# Out:
# Enter first number: 3
# Enter second number: 4
# Enter third number: 5
# The Total is 12
# The Average is 4.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
bill=eval(input("Enter the Bill amount: "))
percentage=eval(input("Enter the percentage tip that you want to leave: "))
tip=bill*(percentage/100)
print("Tip amount is",tip)
print("Bill amount is",bill)
# Out:
# Enter the Bill amount: 4000
# Enter the percentage tip that you want to leave: 10
# Tip amount is 400.0
# Bill amount is 4000
